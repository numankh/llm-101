# %%
import openai
import settings

# %%
api_key = settings.api_key
openai.api_key = api_key

# %%
def generate_text(prompt, max_tokens, temperature):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": prompt}
        ],
        max_tokens=max_tokens,
        temperature=temperature
    )
    return response.choices[0].message.content.strip()

# %%
prompt = "Once upon a time"
generated_text = generate_text(prompt, 5, 0)
print(prompt, generated_text)
# Out:
# Once upon a time , in a faraway

# %%
prompt = "Naruto saw Sasuke"
generated_text = generate_text(prompt, 20, 1)
print(prompt, generated_text)
# Out:
# Naruto saw Sasuke standing at the edge of a cliff, staring out into the distance with a pensive expression on his

# %%
def text_summarizer(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You will be provided with a block of text, and your task is to extract a list of keywords from it."
            },
            {
                "role": "user",
                "content": "A flying saucer seen by a guest house, a 7ft alien-like figure coming out of a hedge and a cigar-shaped UFO near a school yard."
            },
            {
                "role": "assistant",
                "content": "flying saucer, guest house, 7ft alien-like figure, hedge, cigar-shaped UFO, school yard"
            },
            {
                "role": "user",
                "content": "Each April, in the village of Maeliya in northwest Sri Lanka, Pinchal Weldurelage Siriwardene gathers his commmunity under the shade"
            },
            {
                "role": "assistant",
                "content": "Pinchal Weldurelage Siriwardene, Maeliya, northwest Sri Lanka, April"
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        max_tokens=20,
        temperature=0.5
    )
    return response.choices[0].message.content.strip()

# %%
prompt = "Master Reef Guide Kirsty Whiteman didn't need to tell me twice. Peering down through my snorkel mask in the direction of her pointed finger."
summary = text_summarizer(prompt)

# %%
print(summary)
# Out:
# Master Reef Guide, Kirsty Whiteman, snorkel mask, pointed finger
