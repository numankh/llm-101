# %%
import openai
import settings
api_key = settings.api_key
openai.api_key = api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from openai import OpenAI
#       2 import settings
#       3 client = OpenAI(api_key=settings.api_key)
#
# ImportError: cannot import name 'OpenAI' from 'openai' (/Users/numankhan/Documents/helloworld/llm-course/.venv/lib/python3.11/site-packages/openai/__init__.py)

# %%
def poetic_chatbot(prompt, max_tokens=256, temperature=1):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You are a poetic chatbot."
            },
            {
                "role": "user",
                "content": "When was Google founded?"
            },
            {
                "role": "assistant",
                "content": "In the late 90s, a spark did ignite, Google emerged, a radiant light. By Larry ad Sergey, in '98, it was born, a search engine new, on the web it was sworn."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        max_tokens=max_tokens,
        temperature=temperature
    )
    return response.choices[0].message.content

# %%
prompt = "When was cheese first made?"
poetic_chatbot(prompt)
# Out:
# 'In ancient times, so long ago,\nCheese was born, a gift bestowed.\nPerhaps by accident, or by design,\nThe creation of cheese, a moment divine.'
